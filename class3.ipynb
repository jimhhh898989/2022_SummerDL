# %% [markdown]
# <a href="https://colab.research.google.com/github/jimhhh898989/2022_SummerDL/blob/main/class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = "./drive/MyDrive/Colab-Notebooks/class3/bird.jpg"

# %%
image = cv2.imread(path)

# %%
print(type(image))
print(image.shape) # h, w, c
print(image)
# Out:
# <class 'numpy.ndarray'>
# (4068, 2712, 3)
# [[[32 30 20]
#   [32 30 20]
#   [32 30 20]
#   ...
#   [31 29 19]
#   [31 29 19]
#   [31 29 19]]
#
#  [[32 30 20]
#   [32 30 20]
#   [32 30 20]
#   ...
#   [31 29 19]
#   [31 29 19]
#   [31 29 19]]
#
#  [[32 30 20]
#   [32 30 20]
#   [32 30 20]
#   ...
#   [31 29 19]
#   [31 29 19]
#   [31 29 19]]
#
#  ...
#
#  [[33 31 20]
#   [33 31 20]
#   [34 32 21]
#   ...
#   [29 27 16]
#   [29 27 16]
#   [29 27 16]]
#
#  [[33 31 20]
#   [33 31 20]
#   [34 32 21]
#   ...
#   [29 27 16]
#   [29 27 16]
#   [29 27 16]]
#
#  [[33 31 20]
#   [33 31 20]
#   [34 32 21]
#   ...
#   [29 27 16]
#   [29 27 16]
#   [29 27 16]]]

# %%
plt.imshow(image) # cv2 (B, G, R)
plt.show()
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
